# %% [markdown]
# Learning Tensorflow
# ---

# %%
import tensorflow as tf

hello_const = tf.constant('Hello Constant!')

x = tf.placeholder(tf.string)
y = tf.placeholder(tf.int32)
z = tf.placeholder(tf.int32)
w = tf.add(y, z)

with tf.Session() as sess:
    o = sess.run(w, feed_dict={x: 'Test String', y: 123, z: 45})
    print(o)
# Out:
# 168
